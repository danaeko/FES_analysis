# %%
import matplotlib.pyplot  as plt
import sys,os
import numpy as np
import glob
import seaborn as sns
sns.set_style("whitegrid")
import gzip
import pickle
import pandas as pd
import mdtraj as md
import pip
import csv
import itertools
import matplotlib.patches as mpatches
sns.set(style="whitegrid", context='paper')
axes_font_size = 42
label_size = 42
title_size = 42
legend_size = 42
plt.rcParams['xtick.labelsize'] = label_size 
plt.rcParams['ytick.labelsize'] = label_size 
plt.rcParams['axes.labelsize'] = axes_font_size
plt.rcParams['axes.titlesize'] = title_size
#plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"] = 4
sns.set_palette("muted",4)
# Out:
# /home/debian-user/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
df1_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero0.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df1_rmsd_zero_wt['value'] = df1_rmsd_zero_wt['value'] * 10
df2_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero1.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df2_rmsd_zero_wt['value'] = df2_rmsd_zero_wt['value'] * 10
df3_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero2.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df3_rmsd_zero_wt['value'] = df3_rmsd_zero_wt['value'] * 10
df4_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero3.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df4_rmsd_zero_wt['value'] = df4_rmsd_zero_wt['value'] * 10
df5_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero4.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df5_rmsd_zero_wt['value'] = df5_rmsd_zero_wt['value'] * 10
df6_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero5.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df6_rmsd_zero_wt['value'] = df6_rmsd_zero_wt['value'] * 10
df7_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero6.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df7_rmsd_zero_wt['value'] = df7_rmsd_zero_wt['value'] * 10
df8_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero7.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df8_rmsd_zero_wt['value'] = df8_rmsd_zero_wt['value'] * 10
df9_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero8.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df9_rmsd_zero_wt['value'] = df9_rmsd_zero_wt['value'] * 10
df10_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero9.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df10_rmsd_zero_wt['value'] = df10_rmsd_zero_wt['value'] * 10
df11_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero10.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df11_rmsd_zero_wt['value'] = df11_rmsd_zero_wt['value'] * 10
df12_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero11.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df12_rmsd_zero_wt['value'] = df12_rmsd_zero_wt['value'] * 10
df13_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero12.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df13_rmsd_zero_wt['value'] = df13_rmsd_zero_wt['value'] * 10
df14_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero13.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df14_rmsd_zero_wt['value'] = df14_rmsd_zero_wt['value'] * 10
df15_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero14.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df15_rmsd_zero_wt['value'] = df15_rmsd_zero_wt['value'] * 10
df16_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero15.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df16_rmsd_zero_wt['value'] = df16_rmsd_zero_wt['value'] * 10
df16_rmsd_zero_wt['kJ'] = df16_rmsd_zero_wt['kJ'] / 4.184
df17_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero16.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df17_rmsd_zero_wt['value'] = df17_rmsd_zero_wt['value'] * 10
df17_rmsd_zero_wt['kJ'] = df17_rmsd_zero_wt['kJ'] / 4.184
df18_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero17.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df18_rmsd_zero_wt['value'] = df18_rmsd_zero_wt['value'] * 10
df18_rmsd_zero_wt['kJ'] = df18_rmsd_zero_wt['kJ'] / 4.184
df19_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero18.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df19_rmsd_zero_wt['value'] = df19_rmsd_zero_wt['value'] * 10
df19_rmsd_zero_wt['kJ'] = df19_rmsd_zero_wt['kJ'] / 4.184
df20_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero19.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df20_rmsd_zero_wt['value'] = df20_rmsd_zero_wt['value'] * 10
df20_rmsd_zero_wt['kJ'] = df20_rmsd_zero_wt['kJ'] / 4.184
df21_rmsd_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/rmsd_zero20.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df21_rmsd_zero_wt['value'] = df21_rmsd_zero_wt['value'] * 10
df21_rmsd_zero_wt['kJ'] = df21_rmsd_zero_wt['kJ'] / 4.184

df1_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero0.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df2_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero1.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df3_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero2.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df4_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero3.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df5_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero4.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df6_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero5.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df7_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero6.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df8_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero7.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df9_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero8.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df10_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero9.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df11_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero10.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df12_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero11.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df13_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero12.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df14_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero13.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df15_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero14.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df16_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero15.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df16_cmap_zero_wt['kJ'] = df16_cmap_zero_wt['kJ'] / 4.184
df17_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero16.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df17_cmap_zero_wt['kJ'] = df17_cmap_zero_wt['kJ'] / 4.184
df18_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero17.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df18_cmap_zero_wt['kJ'] = df18_cmap_zero_wt['kJ'] / 4.184
df19_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero18.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df19_cmap_zero_wt['kJ'] = df19_cmap_zero_wt['kJ'] / 4.184
df20_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero19.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df20_cmap_zero_wt['kJ'] = df20_cmap_zero_wt['kJ'] / 4.184
df21_cmap_zero_wt= pd.read_csv('/media/debian-user/29451C7161386E7C/METAD_systems/WT/WALKERS_sims/cmap_zero20.dat', sep='\s+', encoding='utf-8', names=['value','kJ'], usecols=['value','kJ'], skipinitialspace=True, skiprows=5)
df21_cmap_zero_wt['kJ'] = df21_cmap_zero_wt['kJ'] / 4.184

# %%
import matplotlib.ticker as ticker
fig, ax = plt.subplots(1, 2, figsize = (40, 13))
ax = ax.flatten()

ax[0].plot(df17_rmsd_zero['value'], df16_rmsd_zero['kJ'], linewidth = 5, label ='85%')
ax[0].plot(df18_rmsd_zero['value'], df17_rmsd_zero['kJ'], linewidth = 5, label ='90%')
ax[0].plot(df19_rmsd_zero['value'], df18_rmsd_zero['kJ'], linewidth = 5, label ='95%')
ax[0].plot(df20_rmsd_zero['value'], df19_rmsd_zero['kJ'], linewidth = 5, label ='100%')

ax[0].set_ylabel('Free Energy (kcal/mol)',fontweight='bold', fontsize=50)
ax[0].set_xlabel('rmsd ($\AA$)',fontweight='bold', fontsize=50)

ax[1].plot(df17_cmap_zero['value'], df17_cmap_zero['kJ'], linewidth = 5, label ='85%')
ax[1].plot(df18_cmap_zero['value'], df18_cmap_zero['kJ'], linewidth = 5, label ='90%')
ax[1].plot(df19_cmap_zero['value'], df19_cmap_zero['kJ'], linewidth = 5, label ='95%')
ax[1].plot(df20_cmap_zero['value'], df20_cmap_zero['kJ'], linewidth = 5, label ='100%')
ax[1].set_xlabel('cmap',fontweight='bold', fontsize=50)

for a in ax:
    a.autoscale(enable=True, axis='x', tight=True)
    a.grid(False)
    a.spines['top'].set_color('black')
    a.spines['top'].set_linewidth(7)
    a.spines['bottom'].set_color('black')
    a.spines['bottom'].set_linewidth(7)
    a.spines['left'].set_color('black')
    a.spines['left'].set_linewidth(7)
    a.spines['right'].set_color('black')
    a.spines['right'].set_linewidth(7)
    a.xaxis.set_tick_params(which='both', color='black', width=10, length=20, direction='in', bottom=True, top=False)
    a.xaxis.get_ticklines()[0].set_linestyle('dashed')
    a.xaxis.get_ticklines()[0].set_dashes([8, 4])
    a.yaxis.set_tick_params(which='both', color='black', width=10, length=20, direction='in', left=True, right=False)
    a.yaxis.get_ticklines()[0].set_linestyle('dashed')

    # Set the tick formatter to format as integers
    a.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
    a.yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
    for tick_label in a.get_xticklabels() + a.get_yticklabels():
        tick_label.set_fontweight('bold')
        tick_label.set_fontsize(50)  # Set tick label font size

    # Adjust tick label padding
    a.tick_params(axis='both', which='both', pad=20)
    
    # Make tick labels bold
    for tick_label in a.get_xticklabels() + a.get_yticklabels():
        tick_label.set_fontweight('bold')
lines = []
labels = []
  
a = fig.axes[0]
Line, Label = a.get_legend_handles_labels()

lines.extend(Line)
labels.extend(Label)
leg = fig.legend(lines, labels, loc='lower center', ncol=8, prop={'size': 40},bbox_to_anchor=(0.51, -0.05),shadow=False, fontsize=22, markerscale=15, edgecolor='none')
for legobj in leg.legendHandles:
    legobj.set_linewidth(15)
    

fig.tight_layout(pad=8.0)

plt.savefig('WT_closed_1D_barrier_percentages_full__.png', dpi=300, transparent=False, bbox_inches='tight',format='png')
